// %%
#include<bits/stdc++.h>
using namespace std;
// NESTING STL

    map<pair<int,int>,int>m;
    pair<int,int>p1,p2;
    p1= {1,2};
    p2 = {3,4};
    cout<<(p1>p2);
    return 0;
// Out:
// 0

// %%
#include<bits/stdc++.h>
using namespace std;
// NESTING STL
// 1 represents true 0 represents false
    map<set<int>,int>m;
   set<int,int>p1,p2;
    p1= {1,2};
    p2 = {3,4};
    cout<<(p1>p2);
    return 0;

// %%
#include<bits/stdc++.h>
using namespace std;

map<pair<string,string>,vector<int>>m;
int n;
cin>>n;
for(int i = 0; i<n; i++){
    string fn, ln;
    int ct;
    cin>>fn>>ln>>ct;
    for(int j = 0; j<ct; j++){
        int x;
        cin>>x;
        m[{fn,ln}].emplace_back(x);
    }
    
}
for(auto &pr:m){
    auto &full_name = pr.first;
    auto &list = pr.second;
      cout<<full_name.first<<" "<<full_name.second<<endl;
    cout<<list.size()<<endl;
    for(auto &ele :list){
        cout<<ele<<" ";
    }
    cout<<endl;
}
cout<<5<<endl;
return 0;
// Out:
// 1
// a b 3
// 1 2 3
// a b
// 3
// 1 2 3
// 5

// %%
sorted order mei pair print honge

// %%
sets mei v pair of int, int rakh skte ho, unordered set mei nahi rakh skte qki wahan hash function use hota h, set v map ki tarah
hi comparison karke leta h

// %%
code monk question hackerearth. qki marks sorted order mei jaa raha th key marks rakhte aur value vector rakhte ek marks ke bohot bacche ho sakte h

// %%
#include<bits/stdc++.h>
using namespace std;
map<int,multiset<string>>m;
int n;
cin>>n;
for(int i = 0; i<n; i++){
    int marks;
    string name;
    cin>>name>>marks;
    m[marks].insert(name);
}
auto cur_it = --m.end();
while(true){
    auto &students = (*cur_it).second;
    int marks = (*cur_it).first;
    for(auto student : students){
        cout<<student<<" "<<marks<<endl;
    }
    if(cur_it == m.begin()) break;
    cur_it--;
}
// Out:
// 4
// Eve 98
// Bob 99
// Alice 78
// Alice 78
// Bob 99
// Eve 98
// Alice 78
// Alice 78

// %%
desecending mei store krne ke liye minus se multiply krke insert karo aur print karne par -1 se multiply kar dea

// %%
//alternate solution
#include<bits/stdc++.h>
using namespace std;
map<int,multiset<string>>m;
int n;
cin>>n;
for(int i = 0; i<n; i++){
    int marks;
    string name;
    cin>>name>>marks;
    m[-1*marks].insert(name);
}
for(auto marks_students_pr : m){
    auto &students = (*marks_students_pr).second;
    int marks = (*marks_students_pr).first;
    for(auto student:students){
        cout<<student<<" "<<-1*marks<<endl;
    }
}
// Out:
// input_line_22:12:10: error: no matching constructor for initialization of 'std::pair<const int, std::multiset<std::__cxx11::basic_string<char>, std::less<std::__cxx11::basic_string<char> >, std::allocator<std::__cxx11::basic_string<char> > > >'
// for(auto marks_students_pr : m){
//          ^                 ~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:315:17: note: candidate constructor not viable: no known conversion from 'std::pair<const int, std::multiset<std::__cxx11::basic_string<char>, std::less<std::__cxx11::basic_string<char> >, std::allocator<std::__cxx11::basic_string<char> > > >' to 'std::pair<const int, std::multiset<std::__cxx11::basic_string<char>, std::less<std::__cxx11::basic_string<char> >, std::allocator<std::__cxx11::basic_string<char> > > > &&' for 1st argument
//       constexpr pair(pair&&) = default;         ///< Move constructor
//                 ^
// ...
